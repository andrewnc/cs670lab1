# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import json

# %%
agents = ["AlwaysDefect","AlwaysCoorperate","TitforTat","NotTitforTat"]

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#                     agent1                   agent2                   agent3  \
# 0  [0.25       0.25000248]  [0.25       0.24999716]  [0.25       0.24999871]
# 1  [0.4        0.39999953]  [0.4        0.39999499]    [0.1       0.1000006]
# 2  [0.1        0.10000122]  [0.1        0.09999995]  [0.4        0.39999752]
# 3  [0.4        0.39999748]  [0.1        0.10000013]  [0.4        0.39999724]
# 4  [0.1        0.10000419]  [0.4        0.39999181]  [0.1        0.09999976]
#
#                     agent4    dynamics                game  gamma  \
# 0  [0.25       0.25000165]  replicator  Prisoner's Dilemma   0.95
# 1  [0.1        0.10000077]  replicator  Prisoner's Dilemma   0.95
# 2  [0.4        0.39999782]  replicator  Prisoner's Dilemma   0.95
# 3  [0.1        0.10000119]  replicator  Prisoner's Dilemma   0.95
# 4  [0.4        0.39999237]  replicator  Prisoner's Dilemma   0.95
#
#    generations_until_stability      initial_distribution
# 0                            2  [0.25, 0.25, 0.25, 0.25]
# 1                            2      [0.4, 0.4, 0.1, 0.1]
# 2                            2      [0.1, 0.1, 0.4, 0.4]
# 3                            2      [0.4, 0.1, 0.4, 0.1]
# 4                            2      [0.1, 0.4, 0.1, 0.4]

# %%
df
# Out:
#                                 agent1                              agent2  \
# 0              [0.25       0.25000248]             [0.25       0.24999716]
# 1              [0.4        0.39999953]             [0.4        0.39999499]
# 2              [0.1        0.10000122]             [0.1        0.09999995]
# 3              [0.4        0.39999748]             [0.1        0.10000013]
# 4              [0.1        0.10000419]             [0.4        0.39999181]
# 5              [0.25       0.24999695]             [0.25       0.25000027]
# 6              [0.4        0.39999943]             [0.4        0.39999497]
# 7              [0.1        0.10000067]             [0.1        0.10000178]
# 8              [0.4        0.39999522]             [0.1        0.10000161]
# 9              [0.1        0.10000104]             [0.4        0.39999493]
# 10             [0.25       0.24999947]             [0.25       0.25000159]
# 11             [0.4        0.39999707]                 [0.4      0.399995]
# 12             [0.1        0.10000132]             [0.1        0.09999955]
# 13             [0.4        0.39999278]             [0.1        0.10000301]
# 14             [0.1        0.09999982]             [0.4        0.39999112]
# 15             [0.25       0.25000054]             [0.25       0.24999835]
# 16             [0.4        0.40000175]             [0.4        0.39999932]
# 17             [0.1        0.10000127]             [0.1        0.09999902]
# 18             [0.4        0.39999884]             [0.1        0.09999919]
# 19             [0.1        0.10000056]             [0.4        0.39999335]
# 20             [0.25       0.24999991]               [0.25      0.2499999]
# 21             [0.4        0.40000122]             [0.4        0.39999999]
# 22             [0.1        0.10000007]             [0.1        0.09999996]
# 23             [0.4        0.39999945]             [0.1        0.10000025]
# 24             [0.1        0.09999972]             [0.4        0.39999999]
# 25             [0.25       0.24999972]             [0.25       0.25000083]
# 26             [0.4        0.39999966]             [0.4        0.40000077]
# 27             [0.1        0.10000125]             [0.1        0.10000014]
# 52  [0.4        0.11222222 0.09333333]  [0.4        0.58111111 0.57333333]
# 53  [0.4        0.12777778 0.08888889]  [0.1        0.10777778 0.12777778]
# 54  [0.1        0.00333333 0.00111111]  [0.4        0.69222222 0.62888889]
# 55  [0.25       0.02666667 0.02      ]  [0.25       0.36666667 0.35      ]
# 56  [0.1        0.00222222 0.00555556]  [0.1        0.17777778 0.17      ]
# 57  [0.4        0.14666667 0.11333333]  [0.4        0.50333333 0.53333333]
# 58  [0.4        0.15222222 0.10888889]  [0.1        0.16777778 0.17777778]
# 59                       [0.1 0.  0. ]  [0.4        0.69333333 0.64333333]
#
#       dynamics                 game  gamma  generations_until_stability  \
# 0   replicator   Prisoner's Dilemma   0.95                            2
# 1   replicator   Prisoner's Dilemma   0.95                            2
# 2   replicator   Prisoner's Dilemma   0.95                            2
# 3   replicator   Prisoner's Dilemma   0.95                            2
# 4   replicator   Prisoner's Dilemma   0.95                            2
# 5   replicator   Prisoner's Dilemma   0.99                            2
# 6   replicator   Prisoner's Dilemma   0.99                            2
# 7   replicator   Prisoner's Dilemma   0.99                            2
# 8   replicator   Prisoner's Dilemma   0.99                            2
# 9   replicator   Prisoner's Dilemma   0.99                            2
# 10  replicator            Stag Hunt   0.95                            2
# 11  replicator            Stag Hunt   0.95                            2
# 12  replicator            Stag Hunt   0.95                            2
# 13  replicator            Stag Hunt   0.95                            2
# 14  replicator            Stag Hunt   0.95                            2
# 15  replicator            Stag Hunt   0.99                            2
# 16  replicator            Stag Hunt   0.99                            2
# 17  replicator            Stag Hunt   0.99                            2
# 18  replicator            Stag Hunt   0.99                            2
# 19  replicator            Stag Hunt   0.99                            2
# 20  replicator  Battle of the Sexes   0.95                            2
# 21  replicator  Battle of the Sexes   0.95                            2
# 22  replicator  Battle of the Sexes   0.95                            2
# 23  replicator  Battle of the Sexes   0.95                            2
# 24  replicator  Battle of the Sexes   0.95                            2
# 25  replicator  Battle of the Sexes   0.99                            2
# 26  replicator  Battle of the Sexes   0.99                            2
# 27  replicator  Battle of the Sexes   0.99                            2
# 28  replicator  Battle of the Sexes   0.99                            2
# 29  replicator  Battle of the Sexes   0.99                            2
# 30    imitator   Prisoner's Dilemma   0.95                            2
# 31    imitator   Prisoner's Dilemma   0.95                            2
# 32    imitator   Prisoner's Dilemma   0.95                            2
# 33    imitator   Prisoner's Dilemma   0.95                            2
# 34    imitator   Prisoner's Dilemma   0.95                            2
# 35    imitator   Prisoner's Dilemma   0.99                            2
# 36    imitator   Prisoner's Dilemma   0.99                            2
# 37    imitator   Prisoner's Dilemma   0.99                            2
# 38    imitator   Prisoner's Dilemma   0.99                            2
# 39    imitator   Prisoner's Dilemma   0.99                            2
# 40    imitator            Stag Hunt   0.95                            2
# 41    imitator            Stag Hunt   0.95                            2
# 42    imitator            Stag Hunt   0.95                            2
# 43    imitator            Stag Hunt   0.95                            2
# 44    imitator            Stag Hunt   0.95                            2
# 45    imitator            Stag Hunt   0.99                            2
# 46    imitator            Stag Hunt   0.99                            2
# 47    imitator            Stag Hunt   0.99                            2
# 48    imitator            Stag Hunt   0.99                            2
# 49    imitator            Stag Hunt   0.99                            2
# 50    imitator  Battle of the Sexes   0.95                            2
# 51    imitator  Battle of the Sexes   0.95                            2
# 52    imitator  Battle of the Sexes   0.95                            2
# 53    imitator  Battle of the Sexes   0.95                            2
# 54    imitator  Battle of the Sexes   0.95                            2
# 55    imitator  Battle of the Sexes   0.99                            2
# 56    imitator  Battle of the Sexes   0.99                            2
# 57    imitator  Battle of the Sexes   0.99                            2
# 58    imitator  Battle of the Sexes   0.99                            2
# 59    imitator  Battle of the Sexes   0.99                            2
#
#         initial_distribution
# 0   [0.25, 0.25, 0.25, 0.25]
# 1       [0.4, 0.4, 0.1, 0.1]
# 2       [0.1, 0.1, 0.4, 0.4]
# 3       [0.4, 0.1, 0.4, 0.1]
# 4       [0.1, 0.4, 0.1, 0.4]
# 5   [0.25, 0.25, 0.25, 0.25]
# 6       [0.4, 0.4, 0.1, 0.1]
# 7       [0.1, 0.1, 0.4, 0.4]
# 8       [0.4, 0.1, 0.4, 0.1]
# 9       [0.1, 0.4, 0.1, 0.4]
# 10  [0.25, 0.25, 0.25, 0.25]
# 11      [0.4, 0.4, 0.1, 0.1]
# 12      [0.1, 0.1, 0.4, 0.4]
# 13      [0.4, 0.1, 0.4, 0.1]
# 14      [0.1, 0.4, 0.1, 0.4]
# 15  [0.25, 0.25, 0.25, 0.25]
# 16      [0.4, 0.4, 0.1, 0.1]
# 17      [0.1, 0.1, 0.4, 0.4]
# 18      [0.4, 0.1, 0.4, 0.1]
# 19      [0.1, 0.4, 0.1, 0.4]
# 20  [0.25, 0.25, 0.25, 0.25]
# 21      [0.4, 0.4, 0.1, 0.1]
# 22      [0.1, 0.1, 0.4, 0.4]
# 23      [0.4, 0.1, 0.4, 0.1]
# 24      [0.1, 0.4, 0.1, 0.4]
# 25  [0.25, 0.25, 0.25, 0.25]
# 26      [0.4, 0.4, 0.1, 0.1]
# 27      [0.1, 0.1, 0.4, 0.4]
# 28      [0.4, 0.1, 0.4, 0.1]
# 29      [0.1, 0.4, 0.1, 0.4]
# 30  [0.25, 0.25, 0.25, 0.25]
# 31      [0.4, 0.4, 0.1, 0.1]
# 32      [0.1, 0.1, 0.4, 0.4]
# 33      [0.4, 0.1, 0.4, 0.1]
# 34      [0.1, 0.4, 0.1, 0.4]
# 35  [0.25, 0.25, 0.25, 0.25]
# 36      [0.4, 0.4, 0.1, 0.1]
# 37      [0.1, 0.1, 0.4, 0.4]
# 38      [0.4, 0.1, 0.4, 0.1]
# 39      [0.1, 0.4, 0.1, 0.4]
# 40  [0.25, 0.25, 0.25, 0.25]
# 41      [0.4, 0.4, 0.1, 0.1]
# 42      [0.1, 0.1, 0.4, 0.4]
# 43      [0.4, 0.1, 0.4, 0.1]
# 44      [0.1, 0.4, 0.1, 0.4]
# 45  [0.25, 0.25, 0.25, 0.25]
# 46      [0.4, 0.4, 0.1, 0.1]
# 47      [0.1, 0.1, 0.4, 0.4]
# 48      [0.4, 0.1, 0.4, 0.1]
# 49      [0.1, 0.4, 0.1, 0.4]
# 50  [0.25, 0.25, 0.25, 0.25]
# 51      [0.4, 0.4, 0.1, 0.1]
# 52      [0.1, 0.1, 0.4, 0.4]
# 53      [0.4, 0.1, 0.4, 0.1]
# 54      [0.1, 0.4, 0.1, 0.4]
# 55  [0.25, 0.25, 0.25, 0.25]
# 56      [0.4, 0.4, 0.1, 0.1]
# 57      [0.1, 0.1, 0.4, 0.4]
# 58      [0.4, 0.1, 0.4, 0.1]
# 59      [0.1, 0.4, 0.1, 0.4]

# %% [markdown]
# ## Use these graphs to find which combinations are 'interesting'

# %%
for i in range(12):
    plays1 = np.array(json.loads(df.iloc[i]['agent1']))
    plays2 = np.array(json.loads(df.iloc[i]['agent2']))
    plays3 = np.array(json.loads(df.iloc[i]['agent3']))
    plays4 = np.array(json.loads(df.iloc[i]['agent4']))
    plt.plot(plays1, label=agents[0])
    plt.plot(plays2, label=agents[1])
    plt.plot(plays3, label=agents[2])
    plt.plot(plays4, label=agents[3])
    plt.title("{}\ngamma: {}".format(df.iloc[i]["game"], df.iloc[i]["gamma"]))
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2565             try:
# -> 2566                 return libts.get_value_box(s, key)
#    2567             except IndexError:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-e57afa39dc78> in <module>()
#       1 for i in range(180):
# ----> 2     plays = np.array(json.loads(df.iloc[i]['theta_progress']))
#       3     plt.plot(plays[:,0], label=df.iloc[i]['agent1'])
#       4     plt.plot(plays[:,1], label=df.iloc[i]['agent2'])
#       5     plt.title("{} vs {} in {}\ngamma: {} theta1: {} theta2: {}".format(df.iloc[i]["agent1"], df.iloc[i]["agent2"], df.iloc[i]["game"], df.iloc[i]["gamma"], df.iloc[i]["initial_theta1"], df.iloc[i]["initial_theta2"]))
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2572                     raise InvalidIndexError(key)
#    2573                 else:
# -> 2574                     raise e1
#    2575             except Exception:  # pragma: no cover
#    2576                 raise e1
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2558         try:
#    2559             return self._engine.get_value(s, k,
# -> 2560                                           tz=getattr(series.dtype, 'tz', None))
#    2561         except KeyError as e1:
#    2562             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'theta_progress'

# %%
df['agent1_cat'] = df.agent1.astype("category").cat.codes
df['agent2_cat'] = df.agent2.astype("category").cat.codes
df['game_cat'] = df['agent1_cat'] + df['agent2_cat']

df.head()

y = df['win']
X = df[['game_cat', 'n_plays']]

mod = sm.OLS(y, X)    # Describe model

res = mod.fit()       # Fit model

print(res.summary())
